# %% [markdown]
# <a href="https://colab.research.google.com/github/sarjakpatel/HousePricePrediction/blob/main/Assignment%204%20Regression%2C%20MLP%20and%20Latent%20Manifolds/CMPE_257_Assignment_4_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xgboost

# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
dataframe = pd.read_csv("/content/drive/MyDrive/Dataset/CMPE 257 - Project/clean_train.csv")

# %%
dataframe.head()
# Out:
#    Unnamed: 0  Id  ...  SaleCondition_Normal  SaleCondition_Partial
# 0           0   1  ...                     1                      0
# 1           1   2  ...                     1                      0
# 2           2   3  ...                     1                      0
# 3           3   4  ...                     0                      0
# 4           4   5  ...                     1                      0
#
# [5 rows x 223 columns]

# %%
dataframe.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'MSSubClass', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2',
#        ...
#        'SaleType_ConLw', 'SaleType_New', 'SaleType_Oth', 'SaleType_WD',
#        'SaleCondition_Abnorml', 'SaleCondition_AdjLand',
#        'SaleCondition_Alloca', 'SaleCondition_Family', 'SaleCondition_Normal',
#        'SaleCondition_Partial'],
#       dtype='object', length=223)

# %%
dataframe = dataframe.drop(['Unnamed: 0', 'Id'], axis = 1)
dataframe
# Out:
#       MSSubClass  LotArea  ...  SaleCondition_Normal  SaleCondition_Partial
# 0             60     8450  ...                     1                      0
# 1             20     9600  ...                     1                      0
# 2             60    11250  ...                     1                      0
# 3             70     9550  ...                     0                      0
# 4             60    14260  ...                     1                      0
# ...          ...      ...  ...                   ...                    ...
# 1452          60     7917  ...                     1                      0
# 1453          20    13175  ...                     1                      0
# 1454          70     9042  ...                     1                      0
# 1455          20     9717  ...                     1                      0
# 1456          20     9937  ...                     1                      0
#
# [1457 rows x 221 columns]

# %%
X = dataframe.drop(['SalePrice'], axis=1)
y = dataframe['SalePrice']

# %%
normalized_X=(X-X.min())/(X.max()-X.min())
normalized_X
# Out:
#       MSSubClass   LotArea  ...  SaleCondition_Normal  SaleCondition_Partial
# 0       0.235294  0.033420  ...                   1.0                    0.0
# 1       0.000000  0.038795  ...                   1.0                    0.0
# 2       0.235294  0.046507  ...                   1.0                    0.0
# 3       0.294118  0.038561  ...                   0.0                    0.0
# 4       0.235294  0.060576  ...                   1.0                    0.0
# ...          ...       ...  ...                   ...                    ...
# 1452    0.235294  0.030929  ...                   1.0                    0.0
# 1453    0.000000  0.055505  ...                   1.0                    0.0
# 1454    0.294118  0.036187  ...                   1.0                    0.0
# 1455    0.000000  0.039342  ...                   1.0                    0.0
# 1456    0.000000  0.040370  ...                   1.0                    0.0
#
# [1457 rows x 220 columns]

# %%
#split the features and labels into  train and test data
X_train, X_test, y_train, y_test = train_test_split(normalized_X, y, test_size=0.2, random_state=1)

# %%
names = ["MLP Regressor", "Random Forest Regressor", "KNeighbours Regressor", "Gradient Boosting Regressor", "XG Boost Regressor"]

# %%
classifiers = [
    MLPRegressor(random_state=1, max_iter=150),
    RandomForestRegressor(max_depth=3, random_state=1, n_estimators=10),
    KNeighborsRegressor(n_neighbors=3),
    GradientBoostingRegressor(random_state=1),
    XGBRegressor()
]

# %%
max_score = 0.0
max_class = ''
# iterate over classifiers
for name, clf in zip(names, classifiers):
    start_time = time.time()
    clf.fit(X_train, y_train)
    score = 100.0 * clf.score(X_test, y_test)
    print('Classifier = %s, Score (test, accuracy) = %.2f,' %(name, score), 'Training time = %.2f seconds' % (time.time() - start_time))
    
    if score > max_score:
        clf_best = clf
        max_score = score
        max_class = name
# Out:
# Classifier = MLP Regressor, Score (test, accuracy) = 85.29, Training time = 6.03 seconds
# Classifier = Random Forest Regressor, Score (test, accuracy) = 74.25, Training time = 0.23 seconds
# Classifier = KNeighbours Regressor, Score (test, accuracy) = 67.37, Training time = 0.05 seconds
# Classifier = Gradient Boosting Regressor, Score (test, accuracy) = 90.52, Training time = 1.13 seconds
# [05:09:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Classifier = XG Boost Regressor, Score (test, accuracy) = 90.24, Training time = 1.20 seconds

# %%
print('Best --> Classifier = %s, Score (test, accuracy) = %.2f' %(max_class, max_score))
#plot the output of the various algorithms
# Out:
# Best --> Classifier = Gradient Boosting Regressor, Score (test, accuracy) = 90.52
